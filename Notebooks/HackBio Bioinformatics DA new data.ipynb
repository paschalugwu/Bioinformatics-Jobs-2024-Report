# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import regex as re
import nltk

# %%
df = pd.read_csv('bfx_jobs_data_30_06_24.csv')

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#                                     Job_title                  company_name  \
# 0    Research Scientist - Bioinformatics III*                 Cube Hub Inc.
# 1                    Bioinformatics Scientist  Centrillion Technology, Inc.
# 2         Single Cell Computational Biologist             Vevo Therapeutics
# 3                        Scientist I/II - R&D          Eitr Biologics, Inc.
# 4  Principal Scientist, Computational Biology          Genesis Therapeutics
#
#                     location   time_posted  num_applicants  \
# 0  California, United States  3 months ago            45.0
# 1              Palo Alto, CA  2 months ago           187.0
# 2    South San Francisco, CA   1 month ago           153.0
# 3              San Diego, CA    1 week ago            96.0
# 4              San Diego, CA  2 months ago             NaN
#
#                       seniority             employment  \
# 0              Mid-Senior level               Contract
# 1              Mid-Senior level              Full-time
# 2                Not Applicable              Full-time
# 3              Mid-Senior level              Full-time
# 4                Not Applicable              Full-time
#
#                                                       function  \
# 0                                                        Other
# 1                Research, Analyst, and Information Technology
# 2                Research, Analyst, and Information Technology
# 3                                                     Research
# 4                Research, Analyst, and Information Technology
#
#                                                                  industries  \
# 0                                                   Staffing and Recruiting
# 1                                                    Biotechnology Research
# 2                                                    Biotechnology Research
# 3              Non-profit Organizations and Primary and Secondary Education
# 4                       Transportation, Logistics, Supply Chain and Storage
#
#             salary  \
# 0              NaN
# 1   $75,000.00/yr
# 2  $120,000.00/yr
# 3  $100,000.00/yr
# 4              NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Centrillion is at the forefront of genomics and synthetic biology, leading the way in spatial genomics, ultra-long DNA sequencing, rapid on-chip sequencing, viral sequencing, genotyping, and synthetic biology. Our advanced technologies and high-density DNA chips are revolutionizing genomic research, making groundbreaking discoveries both accessible and affordable. Our state-of-the-art R&D center is located at 2500 Faber Place, Palo Alto, CA 94303, 8 min away from Stanford campus.Centrillion is a rapidly growing, well-financed and profitable company. Our R&D center in Palo Alto features specialized labs and is equipped with facilities for chemistry and material sciences, molecula ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3  Eitr Biologics, Inc., (Eitr) is a San Diego, CA based biotechnology company focused on the pursuit of novel next generation immunotherapeutics for the treatment of infectious diseases that are a current or emerging threat to public health. Our scientific approach emphasizes the development of technologies that will increase global accessibility to lifesaving immunotherapeutics. Eitr has fostered a robust and highly collaborative worldwide network of academic and government laboratories that share in our scientific goal to address unmet public health needs. Eitr scientists can expect to work in a collaborative atmosphere to advance promising early-stage exploratory technologies to clinical stages of drug development.Eitr currently has an opening for a Scientist I/II - Research and Development position, requiring the qualifications and responsibilities listed below.Responsibilities:Construct design, molecular cloning, multi-piece DNA assembly, site-directed mutagenesis and preparation of phage libraries Design and perform phage display based experiments (e.g., cloning, panning/screening, sequencing, etc.) Generate and characterize stable mammalian cell linesCharacterize antibodies and antibody-based therapeutics (for e.g. affinity, specificity, cross-species binding, epitope determination)Records experimental data and writes data summaries in electronic formatsDraft technical reports, as necessaryPerform protein expression experimentsPerforms experiments including SDS-PAGE, UV/Vis Spectroscopy, ELISA, BLI and Western BlotContributes to writing grant or contract proposalsOther duties as assignedRequirementsBasic Qualifications:Master's Degree in a biology related discipline with 6+ years of experience or Bachelor's Degree with 8+ years of experience in an academic and/or industry settingDemonstrated mastery of standard molecular biology techniques (e.g., primer design, DNA/RNA preparations, PCR, cloning) Experience with antibody phage display including library construction, panning, screening by ELISA and FACS, and characterizationStrong desire to formulate and execute experimental designs in an efficient mannerExperience with mammalian cell tissue culture, transient transfection, and cell line developmentKnowledge of protein biochemistryAbility to follow written procedures/protocols preciselyAbility work independently to complete given tasks and analyze resulting dataGood communication, interpersonal, and teamwork skills are essentialPreferred Qualifications:Ph.D. in a biology related discipline with 0-2 years of post-graduate experience in an academic and/or industry settingExperience with broad set of cell-based assays including reporter assays, FACS competition, ADCC, ADCP, CDCExperience with Biolayer InterferometryExperience independently designing and troubleshooting experimentsExperience with infectious disease immunotherapeuticsExperience with antibody formats including scFv, IgG, VHH, & multi-specificsExperience with bioinformatics software for sequence analysis such as PipeBioPhysical Demands of the Position OfferedThe physical demands described here are representative, but not exhaustive, of those that must be met by an employee to successfully perform the essential functions of this laboratory position. Reasonable accommodations may be made to enable individuals with disabilities to perform these essential functions.On-site role: This is a full-time position that requires the employee to physically report to the jobsite.Lifting and Carrying: This position may require the ability to lift and carry laboratory equipment, glassware, and supplies weighing up to 40 pounds on occasion. Employees should be able to safely use appropriate equipment and follow proper lifting techniques.Fine Motor Skills: Precise fine motor skills are essential for tasks such as pipetting and operating delicate laboratory equipment. Candidates should demonstrate manual dexterity and hand-eye coordination.Standing and Walking: Laboratory work o ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Genesis Therapeutics is pioneering artificial intelligence guided rational drug design to address severe unmet medical needs for patients. Our lab in San Diego is looking for a motivated and multiskilled Principal Scientist, Computational Biology. This is a full-time position in a fast-paced biotech environment with a collegial group of highly productive colleagues working towards well-defined goals. Excellent medical and dental benefits, flexible work hours and vacation days make this an excellent opportunity to learn all aspects of biotech start-up in a supportive and inspiring environment.What You'll DoLead experimental design, execution and analysis of NGS data suc ...

# %%
df.shape
# Out:
# (3025, 11)

# %%
df.seniority.unique()
# Out:
# array(['            Mid-Senior level', '            Not Applicable',
#        '            Entry level', nan, '            Associate',
#        '            Internship', '            Executive',
#        '            Director'], dtype=object)

# %%
df.function.unique(), df.function.nunique()
# Out:
# (array(['              Other',
#         '              Research, Analyst, and Information Technology',
#         '              Research', '              Science and Research',
#         '              Information Technology', '              Science',
#         '              Engineering and Information Technology', nan,
#         '              Management and Manufacturing',
#         '              Administrative',
#         '              Education and Training',
#         '              Training, Consulting, and Customer Service',
#         '              Information Technology, Research, and Science',
#         '              Research, Analyst, and Science',
#         '              Research, Science, and Writing/Editing',
#         '              Information Technology and Analyst',
#         '              Sales and Business Development',
#         '              Analyst',
#         '              Strategy/Planning, Engineering, and Analyst',
#         '              Information Technology and Engineering',
#         '              Engineering, Science, and Information Technology',
#         '              Research and Analyst',
#         '              Design, Information Technology, and Science',
#         '              Information Technology, Research, and Analyst',
#         '              Health Care Provider',
#         '              Research and Science',
#         '              Business Development and Sales',
#         '              Research, Science, and Analyst',
#         '              Marketing, Public Relations, and Writing/Editing',
#         '              Research, Science, and Engineering',
#         '              Project Management and Information Technology',
#         '              Management, Sales, and Science',
#         '              Strategy/Planning, Project Management, and Research',
#         '              Quality Assurance',
#         '              Engineering, Research, and Science',
#         '              Engineering',
#         '              Design, Art/Creative, and Information Technology',
#         '              Design, Science, and Engineering',
#         '              Business Development and Project Management',
#         '              Consulting and Legal', '              Legal',
#         '              Science, Research, and Other',
#         '              Strategy/Planning, Research, and Science',
#         '              Finance and Sales',
#         '              Science, Consulting, and Writing/Editing',
#         '              Production and Manufacturing',
#         '              Sales, Strategy/Planning, and Science',
#         '              Art/Creative',
#         '              Quality Assurance, Science, and Manufacturing',
#         '              Science, Strategy/Planning, and Research',
#         '              Research, Consulting, and Science',
#         '              Other, Information Technology, and Management',
#         '              Strategy/Planning, Sales, and Business Development',
#         '              Product Management',
#         '              Marketing and Sales',
#         '              Public Relations, Business Development, and Consulting',
#         '              Science and Analyst',
#         '              General Business',
#         '              General Business and Other',
#         '              Health Care Provider, Research, and Science',
#         '              Research, Science, and Other',
#         '              Science, Research, and Sales',
#         '              Purchasing and Supply Chain',
#         '              Administrative and Science',
#         '              Human Resources',
#         '              Science, Research, and Analyst',
#         '              Sales',
#         '              Engineering, Quality Assurance, and Research',
#         '              Science and Health Care Provider',
#         '              Other and Science',
#         '              Sales, Business Development, and Analyst',
#         '              Business Development, Strategy/Planning, and Human Resources',
#         '              Science, Information Technology, and Engineering',
#         '              Research, Information Technology, and Science',
#         '              Research, Science, and Information Technology',
#         '              Product Management and Marketing',
#         '              Research and Strategy/Planning',
#         '              Research, Other, and Consulting',
#         '              Research, Science, and Project Management',
#         '              Other, Research, and Science',
#         '              Research, Science, and Health Care Provider',
#         '              Science, Information Technology, and Product Management',
#         '              Strategy/Planning, Science, and Management',
#         '              Engineering and Science',
#         '              Project Management',
#         '              Business Development, Research, and Science',
#         '              Consulting, Research, and Science',
#         '              Manufacturing and Research',
#         '              Writing/Editing, Science, and Other',
#         '              Science, Manufacturing, and Research',
#         '              Research, Project Management, and Strategy/Planning',
#         '              Project Management, Business Development, and Strategy/Planning',
#         '              Manufacturing, Quality Assurance, and Science',
#         '              Accounting/Auditing and Finance',
#         '              Sales, Business Development, and Product Management',
#         '              Consulting, Information Technology, and Sales',
#         '              Finance, Strategy/Planning, and Administrative',
#         '              Design and Strategy/Planning',
#         '              Information Technology and Science',
#         '              Education',
#         '              Information Technology, Product Management, and Science',
#         '              Product Management and Project Management',
#         '              Analyst, Information Technology, and Research',
#         '              Research, Science, and Manufacturing',
#         '              Project Management, Research, and Science',
#         '              Advertising, Public Relations, and Marketing',
#         '              Production',
#         '              Research and Product Management',
#         '              Analyst, Research, and Science',
#         '              Accounting/Auditing',
#         '              Science, Information Technology, and Research',
#         '              Marketing',
#         '              Strategy/Planning, Science, and Research',
#         '              General Business and Engineering',
#         '              Strategy/Planning and Information Technology',
#         '              Information Technology and Research',
#         '              Research, Science, and Training',
#         '              Research, Science, and Education',
#         '              Science and Training',
#         '              Strategy/Planning',
#         '              Engineering and Analyst',
#         '              Strategy/Planning, Research, and Management',
#         '              Finance and Consulting',
#         '              Sales, Advertising, and Business Development',
#         '              Science and Manufacturing',
#         '              Business Development, Science, and Marketing',
#         '              Consulting, Analyst, and Supply Chain',
#         '              Production, Supply Chain, and Manufacturing',
#         '              Analyst and Research',
#         '              Business Development, Management, and Sales',
#         '              Product Management, Science, and Research',
#         '              Engineering and Customer Service',
#         '              Other, Research, and Strategy/Planning',
#         '              Strategy/Planning and Writing/Editing',
#         '              Consulting',
#         '              Research, Management, and Science',
#         '              Science and Customer Service',
#         '              Engineering, Quality Assurance, and Project Management',
#         '              Manufacturing and Science',
#         '              Information Technology, Analyst, and Research',
#         '              Product Management and Research',
#         '              Science, Engineering, and Information Technology',
#         '              Research, Science, and Administrative',
#         '              Research, Science, and Quality Assurance',
#         '              Science, Research, and Strategy/Planning',
#         '              Research and Information Technology',
#         '              Management',
#         '              Science, Analyst, and Engineering',
#         '              Science, Research, and Engineering',
#         '              Science and Information Technology',
#         '              Finance',
#         '              Research, Quality Assurance, and Science',
#         '              Purchasing',
#         '              Research and Management',
#         '              Science and Sales',
#         '              Business Development, Strategy/Planning, and Research',
#         '              Research, Project Management, and Science',
#         '              Other and Legal',
#         '              Business Development',
#         '              Science, Production, and Information Technology',
#         '              Customer Service, Project Management, and Science',
#         '              Sales, Science, and Business Development'],
#        dtype=object),
#  161)

# %%
df.industries.unique(), df.industries.nunique()
# Out:
# (array(['            Staffing and Recruiting',
#         '            Biotechnology Research',
#         '            Non-profit Organizations and Primary and Secondary Education',
#         '            Transportation, Logistics, Supply Chain and Storage',
#         '            Hospitals and Health Care',
#         '            Business Consulting and Services',
#         '            Higher Education',
#         '            Government Administration',
#         '            Biotechnology Research and Research Services',
#         '            Internet Publishing', nan,
#         '            Technology, Information and Internet',
#         '            Biotechnology Research and Health and Human Services',
#         '            Research Services', '            Financial Services',
#         '            Biotechnology',
#         '            Pharmaceutical Manufacturing and Biotechnology Research',
#         '            Pharmaceutical Manufacturing',
#         '            IT Services and IT Consulting',
#         '            Information Technology & Services',
#         '            Pharmaceutical Manufacturing, Research Services, and Biotechnology Research',
#         '            IT Services and IT Consulting, Software Development, and Financial Services',
#         '            Higher Education and Research Services',
#         '            Pharmaceutical Manufacturing, Chemical Manufacturing, and Biotechnology Research',
#         '            Software Development',
#         '            Biotechnology Research, Health and Human Services, and Data Infrastructure and Analytics',
#         '            Information Services and Technology, Information and Internet',
#         '            Biotechnology Research and Hospitals and Health Care',
#         '            Market Research', '            Education Management',
#         '            IT Services and IT Consulting, Software Development, and Computer and Network Security',
#         '            Medical Equipment Manufacturing',
#         '            Research Services, Biotechnology Research, and Pharmaceutical Manufacturing',
#         '            Biotechnology Research, Pharmaceutical Manufacturing, and Research Services',
#         '            Education', '            Medical Practices',
#         '            Internet News',
#         '            Pharmaceutical Manufacturing, Biotechnology Research, and Hospitals and Health Care',
#         '            Chemical Manufacturing, Pharmaceutical Manufacturing, and Biotechnology Research',
#         '            Public Health',
#         '            Biotechnology Research, Hospitals and Health Care, and Medical Equipment Manufacturing',
#         '            Biotechnology Research, Hospitals and Health Care, and Pharmaceutical Manufacturing',
#         '            Mechanical Or Industrial Engineering',
#         '            Biotechnology Research, Research Services, and Pharmaceutical Manufacturing',
#         '            Biotechnology Research and Pharmaceutical Manufacturing',
#         '            Mental Health Care',
#         '            Biotechnology Research and Medical Equipment Manufacturing',
#         '            Civil Engineering, Environmental Services, and Utilities',
#         '            Environmental Services',
#         '            Pharmaceutical Manufacturing, Biotechnology Research, and Medical Equipment Manufacturing',
#         '            Research', '            Human Resources Services',
#         '            Administrative and Support Services',
#         '            Wellness and Fitness Services',
#         '            Biotechnology Research, Research Services, and Software Development',
#         '            Business Consulting and Services, Hospitals and Health Care, and Biotechnology Research',
#         '            Information Services', '            Utilities',
#         '            Defense and Space Manufacturing',
#         '            Food & Beverages',
#         '            Semiconductor Manufacturing',
#         '            Manufacturing and Personal Care Product Manufacturing',
#         '            Chemical Manufacturing and Food and Beverage Services',
#         '            Pharmaceutical Manufacturing and Individual and Family Services',
#         '            Staffing and Recruiting, Pharmaceutical Manufacturing, and Manufacturing',
#         '            Pharmaceutical Manufacturing, Biotechnology Research, and Research Services',
#         '            Biotechnology Research, Pharmaceutical Manufacturing, and Hospitals and Health Care',
#         '            Biotechnology Research, Pharmaceutical Manufacturing, and Appliances, Electrical, and Electronics Manufacturing',
#         '            Biotechnology Research, Research Services, and Hospitals and Health Care',
#         '            Non-profit Organizations',
#         '            Motor Vehicle Manufacturing',
#         '            Biotechnology Research, Government Relations Services, and Research Services',
#         '            Museums, Historical Sites, and Zoos and Museums',
#         '            Pharmaceutical Manufacturing, Medical Equipment Manufacturing, and Biotechnology Research',
#         '            Hospitals and Health Care, Pharmaceutical Manufacturing, and Medical Equipment Manufacturing',
#         '            Business Consulting and Services and IT Services and IT Consulting',
#         '            Medical Equipment Manufacturing, Hospitals and Health Care, and Biotechnology Research',
#         '            Wellness and Fitness Services and Hospitals and Health Care',
#         '            Research Services and Hospitals and Health Care',
#         '            Chemical Manufacturing, Manufacturing, and Retail Luxury Goods and Jewelry',
#         '            Non-profit Organizations and Health and Human Services',
#         '            Software Development, Biotechnology Research, and Pharmaceutical Manufacturing',
#         '            Consumer Services, IT Services and IT Consulting, and Technology, Information and Internet',
#         '            Health and Human Services',
#         '            Food and Beverage Manufacturing',
#         '            Chemical Manufacturing',
#         '            Strategic Management Services',
#         '            Biotechnology Research, Chemical Manufacturing, and Pharmaceutical Manufacturing',
#         '            Staffing and Recruiting and Pharmaceutical Manufacturing',
#         '            Biotechnology Research, Medical Practices, and Pharmaceutical Manufacturing',
#         '            Book and Periodical Publishing, Broadcast Media Production and Distribution, and Advertising Services',
#         '            Civil Engineering',
#         '            Advertising Services',
#         '            Food and Beverage Manufacturing, Food and Beverage Services, and Manufacturing',
#         '            Research Services, Biotechnology Research, and IT Services and IT Consulting',
#         '            Nanotechnology Research',
#         '            Research Services, Pharmaceutical Manufacturing, and Biotechnology Research',
#         '            Chemical Manufacturing and Industrial Machinery Manufacturing',
#         '            Civic and Social Organizations and Non-profit Organizations',
#         '            Financial Services, Banking, and Investment Banking',
#         '            Manufacturing',
#         '            Manufacturing and Medical Practices',
#         '            Medical Equipment Manufacturing, Research Services, and Biotechnology Research',
#         '            Biotechnology Research, Research Services, and Medical Equipment Manufacturing',
#         '            Technology, Information and Media',
#         '            International Affairs',
#         '            Wellness and Fitness Services, Biotechnology Research, and Pharmaceutical Manufacturing',
#         '            Transportation, Logistics, Supply Chain and Storage, Internet Publishing, and Internet Publishing',
#         '            Design Services',
#         '            Automation Machinery Manufacturing',
#         '            Biotechnology Research, Environmental Services, and Pharmaceutical Manufacturing',
#         '            Glass, Ceramics and Concrete Manufacturing',
#         '            Software Development, IT Services and IT Consulting, and Business Consulting and Services',
#         '            Human Resources Services, Biotechnology Research, and Medical Equipment Manufacturing',
#         '            Biotechnology Research, Pharmaceutical Manufacturing, and Nanotechnology Research',
#         '            Technology, Information and Internet and IT Services and IT Consulting',
#         '            IT Services and IT Consulting and Technology, Information and Internet',
#         '            Higher Education, Non-profit Organizations, and Research Services',
#         '            Education Administration Programs, Higher Education, and Research Services',
#         '            Hospitals and Health Care, Biotechnology Research, and Pharmaceutical Manufacturing',
#         '            Biotechnology Research, Medical Equipment Manufacturing, and Pharmaceutical Manufacturing',
#         '            Biotechnology Research, Chemical Manufacturing, and Hospitals and Health Care',
#         '            Computer Hardware Manufacturing, Software Development, and Computers and Electronics Manufacturing',
#         '            Architecture and Planning',
#         '            Financial Services and Hospitals and Health Care',
#         '            Pharmaceutical Manufacturing and Public Health',
#         '            Government Relations Services',
#         '            Food and Beverage Manufacturing and Biotechnology Research',
#         '            Research Services and Biotechnology Research',
#         '            Biotechnology Research and Machinery Manufacturing',
#         '            Software Development and Transportation, Logistics, Supply Chain and Storage',
#         '            Industrial Machinery Manufacturing',
#         '            Industrial Machinery Manufacturing and Chemical Manufacturing',
#         '            Biotechnology Research, Pharmaceutical Manufacturing, and Software Development',
#         '            Computer and Network Security and IT Services and IT Consulting',
#         '            Accounting, IT Services and IT Consulting, and Business Consulting and Services',
#         '            Research Services, Biotechnology Research, and Government Relations Services',
#         '            Research Services, Biotechnology Research, and Public Health',
#         '            Defense and Space Manufacturing, Appliances, Electrical, and Electronics Manufacturing, and Oil and Gas',
#         '            Education Administration Programs',
#         '            Oil and Gas',
#         '            Appliances, Electrical, and Electronics Manufacturing and Industrial Machinery Manufacturing',
#         '            Biotechnology Research, IT Services and IT Consulting, and Medical Equipment Manufacturing',
#         '            Insurance',
#         '            Software Development, IT Services and IT Consulting, and Research Services',
#         '            Chemical Manufacturing, Agricultural Chemical Manufacturing, and Food and Beverage Manufacturing',
#         '            Travel Arrangements',
#         '            Professional Services, Technology, Information and Media, and Financial Services',
#         '            Biotechnology Research, Pharmaceutical Manufacturing, and Medical Equipment Manufacturing',
#         '            Research Services and Non-profit Organizations',
#         '            Staffing and Recruiting and Software Development',
#         '            Biotechnology Research, Pharmaceutical Manufacturing, and Technology, Information and Internet',
#         '            Executive Search Services',
#         '            Financial Services and Technology, Information and Internet',
#         '            Investment Management',
#         '            Individual and Family Services',
#         '            Hospitality',
#         '            Wellness and Fitness Services, Medical Practices, and Hospitals and Health Care',
#         '            Research Services, Biotechnology Research, and Software Development',
#         '            Medical Equipment Manufacturing, Software Development, and Biotechnology Research',
#         '            Biotechnology Research and Technology, Information and Media',
#         '            Information Services, Research Services, and Biotechnology Research',
#         '            Computer Hardware Manufacturing',
#         '            Research Services, Chemical Manufacturing, and Technology, Information and Media',
#         '            Appliances, Electrical, and Electronics Manufacturing',
#         '            Book and Periodical Publishing',
#         '            Transportation, Logistics, Supply Chain and Storage and Internet Publishing',
#         '            Hospitals and Health Care, IT Services and IT Consulting, and Research Services',
#         '            Software Development, Technology, Information and Internet, and Technology, Information and Media',
#         '            Business Consulting and Services and Services for Renewable Energy',
#         '            Manufacturing, Food and Beverage Services, and Food and Beverage Manufacturing',
#         '            Construction',
#         '            Staffing and Recruiting and Biotechnology Research'],
#        dtype=object),
#  172)

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_desc = df['description'].head(5)
print(df_desc.head())
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Centrillion is at the forefront of genomics and synthetic biology, leading the way in spatial genomics, ultra-long DNA sequencing, rapid on-chip sequencing, viral sequencing, genotyping, and synthetic biology. Our advanced technologies and high-density DNA chips are revolutionizing genomic research, making groundbreaking discoveries both accessible and affordable. Our state-of-the-art R&D center is located at 2500 Faber Place, Palo Alto, CA 94303, 8 min away from Stanford campus.Centrillion is a rapidly growing, well-financed and profitable company. Our R&D center in Palo Alto features specialized labs and is equipped with facilities for chemistry and material sciences, molecu ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3    Eitr Biologics, Inc., (Eitr) is a San Diego, CA based biotechnology company focused on the pursuit of novel next generation immunotherapeutics for the treatment of infectious diseases that are a current or emerging threat to public health. Our scientific approach emphasizes the development of technologies that will increase global accessibility to lifesaving immunotherapeutics. Eitr has fostered a robust and highly collaborative worldwide network of academic and government laboratories that share in our scientific goal to address unmet public health needs. Eitr scientists can expect to work in a collaborative atmosphere to advance promising early-stage exploratory technologies to clinical stages of drug development.Eitr currently has an opening for a Scientist I/II - Research and Development position, requiring the qualifications and responsibilities listed below.Responsibilities:Construct design, molecular cloning, multi-piece DNA assembly, site-directed mutagenesis and preparation of phage libraries Design and perform phage display based experiments (e.g., cloning, panning/screening, sequencing, etc.) Generate and characterize stable mammalian cell linesCharacterize antibodies and antibody-based therapeutics (for e.g. affinity, specificity, cross-species binding, epitope determination)Records experimental data and writes data summaries in electronic formatsDraft technical reports, as necessaryPerform protein expression experimentsPerforms experiments including SDS-PAGE, UV/Vis Spectroscopy, ELISA, BLI and Western BlotContributes to writing grant or contract proposalsOther duties as assignedRequirementsBasic Qualifications:Master's Degree in a biology related discipline with 6+ years of experience or Bachelor's Degree with 8+ years of experience in an academic and/or industry settingDemonstrated mastery of standard molecular biology techniques (e.g., primer design, DNA/RNA preparations, PCR, cloning) Experience with antibody phage display including library construction, panning, screening by ELISA and FACS, and characterizationStrong desire to formulate and execute experimental designs in an efficient mannerExperience with mammalian cell tissue culture, transient transfection, and cell line developmentKnowledge of protein biochemistryAbility to follow written procedures/protocols preciselyAbility work independently to complete given tasks and analyze resulting dataGood communication, interpersonal, and teamwork skills are essentialPreferred Qualifications:Ph.D. in a biology related discipline with 0-2 years of post-graduate experience in an academic and/or industry settingExperience with broad set of cell-based assays including reporter assays, FACS competition, ADCC, ADCP, CDCExperience with Biolayer InterferometryExperience independently designing and troubleshooting experimentsExperience with infectious disease immunotherapeuticsExperience with antibody formats including scFv, IgG, VHH, & multi-specificsExperience with bioinformatics software for sequence analysis such as PipeBioPhysical Demands of the Position OfferedThe physical demands described here are representative, but not exhaustive, of those that must be met by an employee to successfully perform the essential functions of this laboratory position. Reasonable accommodations may be made to enable individuals with disabilities to perform these essential functions.On-site role: This is a full-time position that requires the employee to physically report to the jobsite.Lifting and Carrying: This position may require the ability to lift and carry laboratory equipment, glassware, and supplies weighing up to 40 pounds on occasion. Employees should be able to safely use appropriate equipment and follow proper lifting techniques.Fine Motor Skills: Precise fine motor skills are essential for tasks such as pipetting and operating delicate laboratory equipment. Candidates should demonstrate manual dexterity and hand-eye coordination.Standing and Walking: Laboratory work ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Genesis Therapeutics is pioneering artificial intelligence guided rational drug design to address severe unmet medical needs for patients. Our lab in San Diego is looking for a motivated and multiskilled Principal Scientist, Computational Biology. This is a full-time position in a fast-paced biotech environment with a collegial group of highly productive colleagues working towards well-defined goals. Excellent medical and dental benefits, flexible work hours and vacation days make this an excellent opportunity to learn all aspects of biotech start-up in a supportive and inspiring environment.What You'll DoLead experimental design, execution and analysis of NGS data s ...
# Name: description, dtype: object

# %% [markdown]
# ## Cleaning description column

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %% [markdown]
# ### Clean HTML tags and special characters then lemmatize words in the description column

# %%
# Clean HTML tags and special characters
def clean_text(text):
    if isinstance(text, str):
        # Preserve sequences like "scrna-seq", "atac-seq", "scRNA-seq", etc.
        seq_patterns = re.findall(r'\b[a-zA-Z]+-seq\b', text)
        
        # Remove HTML tags
        text = re.sub(r'<.*?>', '', text)
        
        # Remove non-alphanumeric characters except spaces, 'R', and specific punctuation marks
        text = re.sub(r'[^a-zA-Z0-9\sR.,;:-]', '', text)
        
        # Append preserved patterns (if any) to the cleaned text
        for pattern in seq_patterns:
            text += f" {pattern}"
        
        # Remove leading and trailing spaces
        text = text.strip()
    else:
        text = ''
    return text


df['cleaned_description'] = df['description'].apply(clean_text)

# insert space after punctuation the remove non-alphanumeric characters
def insert_space_after_punctuation(text):
    text = re.sub(r'(\.)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'(\,)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'(\;)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'(\:)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'[^a-zA-Z0-9\sR]', '', text)
    return text

df['cleaned_description'] = df['cleaned_description'].apply(insert_space_after_punctuation)

# Tokenize and remove stopwords
stop_words = set(stopwords.words('english'))

def tokenize_and_remove_stopwords(text):
    words = word_tokenize(text)
    words = [word for word in words if word.lower() not in stop_words]
    return words

df['tokens'] = df['cleaned_description'].apply(tokenize_and_remove_stopwords)

# Lemmatize words
lemmatizer = WordNetLemmatizer()

def lemmatize_words(words):
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return lemmatized_words

df['lemmatized_tokens'] = df['tokens'].apply(lemmatize_words)

# Convert tokens back to string
def tokens_to_string(tokens):
    return ' '.join(tokens)

df['final_cleaned_description'] = df['lemmatized_tokens'].apply(tokens_to_string)

# %%
# Clean HTML tags and special characters# Define a list of specific -seq patterns to preserve
seq_types = ['scrna-seq', 'atac-seq', 'rna-seq', 'chip-seq']  # Add more patterns as needed

def clean_text(text):
    if isinstance(text, str):
        # Create a regex pattern from the list of seq_types
        seq_pattern = '|'.join(re.escape(seq) for seq in seq_types)
        
        # Preserve sequences like "scrna-seq", "atac-seq", etc.
        seq_matches = re.findall(seq_pattern, text, re.IGNORECASE)
        
        # Remove HTML tags
        text = re.sub(r'<.*?>', '', text)
        
        # Remove non-alphanumeric characters except spaces and specific punctuation
        text = re.sub(r'[^a-zA-Z0-9\sR.,;:-]', '', text)
        
        # Remove the preserved sequences to reinsert them later
        text = re.sub(seq_pattern, '', text, flags=re.IGNORECASE)
        
        # Reinsert preserved "-seq" patterns
        text += ' ' + ' '.join(seq_matches)
        
        # Remove extra spaces
        text = re.sub(r'\s+', ' ', text).strip()
    else:
        text = ''
    return text

df['cleaned_description'] = df['description'].apply(clean_text)

def insert_space_after_punctuation(text):
    seq_pattern = '|'.join(re.escape(seq) for seq in seq_types)
    seq_matches = re.findall(seq_pattern, text, re.IGNORECASE)
    text = re.sub(seq_pattern, '<SEQ>', text, flags=re.IGNORECASE)
    text = re.sub(r'(\.)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'(\,)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'(\;)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'(\:)([A-Za-z])', r'\1 \2', text)
    text = re.sub(r'[^a-zA-Z0-9\sR]', '', text)
    for match in seq_matches:
        text = re.sub('<SEQ>', match, text, 1)
    return text

df['cleaned_description'] = df['cleaned_description'].apply(insert_space_after_punctuation)

stop_words = set(stopwords.words('english'))
def tokenize_and_remove_stopwords(text):
    words = word_tokenize(text)
    words = [word for word in words if word.lower() not in stop_words]
    return words

df['tokens'] = df['cleaned_description'].apply(tokenize_and_remove_stopwords)

lemmatizer = WordNetLemmatizer()
def lemmatize_words(words):
    return [lemmatizer.lemmatize(word) for word in words]

df['lemmatized_tokens'] = df['tokens'].apply(lemmatize_words)

def tokens_to_string(tokens):
    return ' '.join(tokens)

df['final_cleaned_description'] = df['lemmatized_tokens'].apply(tokens_to_string)

# %% [markdown]
# ### Check for skills, tools and technologies and academic qualifications in the job descriptions

# %%
# Updated lists of tools, technologies, skills, and qualifications
tools_technologies = [
    "Microsoft Office", "Microsoft Suite", "Excel", "Python", "Perl", "HTML", "R", "SharePoint", "bash", "SQL", "mssql", "mysql", "PowerBI", "Power BI",
    "Tableau", "SPSS", "Matlab", "SAS", "Teams", "Rservers", "Rshiny", "RMarkdown", "VBA", "Visual Basic for Applications",
    "KEGG", "Reactome", "PDB", "Shiny", "Unix", "Scrum", "Kanban",
    "Java", "C++", "JavaScript", "Docker", "Conda", "Git", "GitHub",
    "Hamilton Star", "Beckman Echo", "AWS", "GCP", "Azure",
    "CRISPR", "RNA-Seq", "ChIP-Seq", "ATAC-Seq", "scRNA-Seq", "Hi-C", "STAR",
    "WGS", "NGS", "RNA-Seq", "Bulk Sequencing", "Single Cell Sequencing", "BS-Seq", "Epigenetics",
    "Machine Learning", "ML", "Artificial Intelligence", "Deep Learning", "CNN", "Convolutional Neural Network", "Perturb-Seq", "Imaging", "AI",
    "Wet Lab", "Dry Lab", "Wet and Dry Lab", "Research", "Sequencing",
    "REST API", "TCGA", "DepMap", "gnomAD", "NCBI SRA", "ENCODE"
]

skills = [
    "Machine Learning", "ML", "Artificial Intelligence", "Deep Learning", "CNN", "Convolutional Neural Network", "Perturb-Seq", "Imaging", "AI",
    "Wet Lab", "Dry Lab", "Wet and Dry Lab", "Research", "Sequencing",
    "CRISPR", "Perturb-Seq", "Database", "Databases",
    "Bioinformatics", "Statistical Analyses", "Data Science", "Data Analytics", "Data Analysis", "Data Visualization",
    'Python', 'R', 'Java', 'C++', 'JavaScript'
]

qualifications = [
    "BSc", "bsc", "bachelor's", "bachelors", "msc", "MSc", "M.S", "M.S.", "M.Sc", "MSc", 
    "PhD", "Ph.D", "p.hd", "ph.d", "undergraduate", "masters", "master's", "master", "doctorate", "doctoral", "postdoc", "post-doc"
]

# Mappings for standardizing terms
tools_mapping = {
    "vba": "VBA",
    "visual basic for applications": "VBA",
    "power bi": "Power BI",
    "powerbi": "Power BI",
    "sql": "SQL",
    "mssql": "SQL",
    "mysql": "SQL",
    "microsoft suite": "Microsoft Office"
}

skills_mapping = {
    "data analysis": "Data Analysis",
    "data analytics": "Data Analysis",
    "database": "Databases",
    "databases": "Databases",
    "convolutional neural network": "CNN",
    "artificial intelligence": "AI"
}

qualification_mapping = {
    "bsc": "Bachelor's",
    "bachelor's": "Bachelor's",
    "bachelors": "Bachelor's",
    "msc": "Master's",
    "m.s": "Master's",
    "m.s.": "Master's",
    "m.sc": "Master's",
    "masters": "Master's",
    "master's": "Master's",
    "master": "Master's",
    "phd": "Doctorate",
    "ph.d": "Doctorate",
    "p.hd": "Doctorate",
    "ph.d.": "Doctorate",
    "doctorate": "Post Doctorate",
    "doctoral": "Post Doctorate",
    "postdoc": "Post Doctorate",
    "post-doc": "Post Doctorate",
    "undergraduate": "Undergraduate"
}

# Functions to check for tools, skills, and qualifications
def check_for_terms(text, terms):
    """ Generic function to check for any set of terms in a text """
    if isinstance(text, str):
        text = text.lower()
        found_terms = []
        for term in terms:
            if term.lower() in text:
                found_terms.append(term)
        return found_terms
    else:
        return []

# Functions to standardize tools, skills, and qualifications
def standardize_terms(term_list, mapping):
    return [mapping.get(term.lower(), term) for term in term_list]

# Apply the functions to the cleaned descriptions
df['tools_found'] = df['final_cleaned_description'].apply(lambda x: check_for_terms(x, tools_technologies))
df['tools_found'] = df['tools_found'].apply(lambda x: standardize_terms(x, tools_mapping))

df['skills_found'] = df['final_cleaned_description'].apply(lambda x: check_for_terms(x, skills))
df['skills_found'] = df['skills_found'].apply(lambda x: standardize_terms(x, skills_mapping))

df['academic_qualification'] = df['description'].apply(lambda x: check_for_terms(x, qualifications))
df['academic_qualification'] = df['academic_qualification'].apply(lambda x: standardize_terms(x, qualification_mapping))

# Ensure there are no unnecessary steps that remove words needed for counting later
# Your colleague's previous steps are effectively integrated and simplified

# %%
# Display the dataframe with the new column
df[['final_cleaned_description', 'tools_found', 'skills_found', 'academic_qualification']].head()


# Display the final cleaned descriptions
# print(df['final_cleaned_description'].head())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        DescriptionResearch Scientist Bioinformatics Consultant Molecular EpidemiologyThe Biomarker Sciences department client dedicated conduct biomarker translational research understanding specific aspect biology inform research development pipeline decision advance effectiveness available therapy appropriate patient population Molecular Epidemiology team support biomarker activity integrating realworld data epidemiologic evidence within biomarker discovery development strategy Responsibilities Responsibilities include limited following conduct statistical analysis realworld observational clinicogenomic data Tempus publicly available database e ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Centrillion forefront genomics synthetic biology leading way spatial genomics ultralong DNA sequencing rapid onchip sequencing viral sequencing genotyping synthetic biology advanced technology highdensity DNA chip revolutionizing genomic research making groundbreaking discovery accessible affordable stateoftheart RD center located 2500 Faber Place Palo Alto CA 94303 8 min away Stanford campus Centrillion rapidly growing wellfinanced profitable company RD center Palo Alto feature specialized lab equipped facility chemistry material science molecular biology lithographic clean room advanced research tool research center foster innovation maintains open culture scientist currently focused decoding real genome realizing next generation smart manufacturing technology Centillions highdensity DNA chip benefit multidisciplinary approach integrating material science molecular biology diverse engineering discipline including microfabrication efficient coding algorithm design chip also capitalize advance optic microfabrication material science genomics artificial intelligence develop powerful genomics tool require highly multidisciplinary research team Key Responsibilities Develop implement advanced computational statistical method analyzing largescale genomic data field spatial genomics long DNA sequencing Collaborate molecular b ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Vevo TherapeuticsWe biotechnology company based San Francisco using vivo drug discovery platform AI model trained data uncover better drug patient Mosaic platform first make vivo data generation scalable singlecell precision capture vivo context disease first step drug discovery better represent patient diversity drug response current vitro assay using Mosaic build world largest vivo atlas drug interact patient cell alter gene  ...
# 3  Eitr Biologics Inc Eitr San Diego CA based biotechnology company focused pursuit novel next generation immunotherapeutics treatment infectious disease current emerging threat public health scientific approach emphasizes development technology increase global accessibility lifesaving immunotherapeutics Eitr fostered robust highly collaborative worldwide network academic government laboratory share scientific goal address unmet public health need Eitr scientist expect work collaborative atmosphere advance promising earlystage exploratory technology clinical stage drug development Eitr currently opening Scientist III Research Development position requiring qualification responsibility listed Responsibilities Construct design molecular cloning multipiece DNA assembly sitedirected mutagenesis preparation phage library Design perform phage display based experiment e g cloning panningscreening sequencing etc Generate characterize stable mammalian cell linesCharacterize antibody antibodybased therapeutic e g affinity specificity crossspecies binding epitope determinationRecords experimental data writes data summary electronic formatsDraft technical report necessaryPerform protein expression experimentsPerforms experiment including SDSPAGE UVVis Spectroscopy ELISA BLI Western BlotContributes writing grant contract proposalsOther duty assignedRequirementsBasic Qualifications Masters Degree biology related discipline 6 year experience Bachelors Degree 8 year experience academic andor industry settingDemonstrated mastery standard molecular biology technique e g primer design DNARNA preparation PCR cloning Experience antibody phage display including library construction panning screening ELISA FACS characterizationStrong desire formulate execute experimental design efficient mannerExperience mammalian cell tissue culture transient transfection cell line developmentKnowledge protein biochemistryAbility follow written proceduresprotocols preciselyAbility work independently complete given task analyze resulting dataGood communication interpersonal teamwork skill essentialPreferred Qualifications Ph biology related discipline 02 year postgraduate experience academic andor industry settingExperience broad set cellbased assay including reporter assay FACS competition ADCC ADCP CDCExperience Biolayer InterferometryExperience independently designing troubleshooting experimentsExperience infectious disease immunotherapeuticsExperience antibody format including scFv IgG VHH multispecificsExperience bioinformatics software sequence analysis PipeBioPhysical Demands Position OfferedThe physical demand described representative exhaustive must met employee successfully perform essential function laboratory position Reasonable accommodation may made enable individual disability perform essential function Onsite role fulltime position requires employee physically report jobsite Lifting Carrying position may require ability lift carry laboratory equipment glassware supply weighing 40 pound occasion Employees able safely use appropriate equipment follow proper lifting technique Fine Motor Skills Precise fine motor skill essential task pipetting operating delicate laboratory equipment Candidates demonstrate manual dexterity handeye coordination Standing Walking Laboratory work often involves prolonged period standing walking conducting experiment monitoring equipment moving workstation Sitting Data analysis documentation report writing integral aspect role requiring ability sit desk workstation extended period Bending Stooping Reaching Employees may required bend stoop reach access equipment sample material upper lower shelf within laboratory hood activity may involve climbing ladder stair step stool structure Candidates able safely perform task Vision Good vision essential task reading label observing specimen using microscope Corrected vision color vision may required accurate analysis Hearing Laboratory environment may include equipment produce noise Ad ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Genesis Therapeutics pioneering artificial intelligence guided rational drug design address severe unmet medical need patient lab San Diego looking motivated multiskilled Principal Scientist Computational Biology fulltime position fastpaced biotech environment collegial group highly productive colleague working towards welldefined goal Excellent medical dental benefit flexible work hour vacation day make excellent opportunity learn aspect biotech startup supportive inspiring environment Youll DoLead experimental design execution analysis NGS data DNA sequencing Transcriptomics Epigenomics endpoint pharmacological genetic interventionsApply machine learning bionetwork analysis cuttingedge bioinformatic methodology identify new target patient stratification strategy responsive biomarkersDevelop method interrogate public Omics databasesLead development computational method integrative analysis visualization genomics dataCollaborate Biology Chemistry DMPK Computer Engineering leverage tissuespecific genomics data mean target identification validationOversee genomics data managementWhat Youll BringPhD Computer Science Bioinformatics 6 year Industry experience strong publication recordUtilizing transcriptome data derive predictive pharmacodynamic gene expression signature preclinical clinical genomics dataKnowledge experience structural analysis plusExperience implementing maintaining running analysis w ...
#
#                                                                                                      tools_found  \
# 0                                                              [Python, R, Machine Learning, AI, Research, TCGA]
# 1                                          [Excel, Python, R, Artificial Intelligence, AI, Research, Sequencing]
# 2                                                         [Python, R, NGS, Machine Learning, ML, AI, Sequencing]
# 3                                                                             [R, NGS, AI, Research, Sequencing]
# 4  [Excel, R, STAR, NGS, Machine Learning, ML, Artificial Intelligence, Deep Learning, AI, Research, Sequencing]
#
#                                                                                                                        skills_found  \
# 0                                              [Machine Learning, AI, Research, Databases, Bioinformatics, Data Science, Python, R]
# 1                                               [AI, AI, Research, Sequencing, Databases, Bioinformatics, Data Analysis, Python, R]
# 2                                                  [Machine Learning, ML, AI, Sequencing, Bioinformatics, Data Analysis, Python, R]
# 3                                                                      [AI, Research, Sequencing, Bioinformatics, Data Analysis, R]
# 4  [Machine Learning, ML, AI, Deep Learning, AI, Research, Sequencing, Databases, Databases, Bioinformatics, Data Visualization, R]
#
#                                         academic_qualification
# 0  [Doctorate, Doctorate, Doctorate, Master's, Post Doctorate]
# 1                                                           []
# 2                                                  [Doctorate]
# 3       [Bachelor's, Doctorate, Doctorate, Master's, Master's]
# 4                                                  [Doctorate]

# %%
# Define categories for tools and skills
categories = {
    "Programming Languages": [
        "Python", "R", "Java", "C++", "Javascript", "bash", "SQL", "Perl", "HTML",
    ],
    "Cloud Platforms": [
        "AWS", "GCP", "Azure"
    ],
    "Data Visualization": [
        "Power BI", "Tableau", "SPSS"
    ],
    "Sequencing Technologies": [
        "RNA-seq", "ChIP-seq", "ATAC-seq", "scRNA-seq", "WGS", "Bulk Sequencing", "Single Cell Sequencing"
    ],
    "Machine Learning & AI": [
        "Machine Learning", "Deep Learning", "AI", "CNN"
    ],
    "Bioinformatics": [
        "CRISPR", "Perturb-Seq", "Imaging", "REST API"
    ],
    "Databases": [
        "TCGA", "DepMap", "gnomAD", "NCBI SRA", "ENCODE", "SQL"
    ],
    "Other Tools": [
        "Microsoft Office", "Excel", "SharePoint", "Teams", "Rservers", "Rshiny", "RMarkdown", "VBA",
        "KEGG", "Reactome", "PDB", "Shiny", "Unix", "Hamilton Star", "Beckman Echo", "Scrum", "Kanban",
        "Docker", "Conda", "Git", "GitHub"
    ]
}

# Function to categorize tools and skills
def categorize_tools(tools_found, categories):
    # Initialize category counts to zero
    categorized = {category: 0 for category in categories.keys()}
    
    # Iterate over each category and its items
    for category, items in categories.items():
        # Iterate over each item in the tools_found list
        for tool in tools_found:
            # If the tool is found in the category list, increment the count
            if tool in items:
                categorized[category] += 1
    
    return categorized

# Apply the categorization function to each job description
categorized_df = df['tools_found'].apply(lambda x: categorize_tools(x, categories))

# Convert the list of dictionaries into a DataFrame
categorized_df = pd.DataFrame(categorized_df.tolist())

# Concatenate the categorized DataFrame with the original DataFrame
df_final = pd.concat([df, categorized_df], axis=1)

# Optionally, you can save or view the resulting DataFrame
# df_final.to_csv('categorized_job_descriptions.csv', index=False)
df_final.head()
# Out:
#                                     Job_title                  company_name  \
# 0    Research Scientist - Bioinformatics III*                 Cube Hub Inc.
# 1                    Bioinformatics Scientist  Centrillion Technology, Inc.
# 2         Single Cell Computational Biologist             Vevo Therapeutics
# 3                        Scientist I/II - R&D          Eitr Biologics, Inc.
# 4  Principal Scientist, Computational Biology          Genesis Therapeutics
#
#                     location   time_posted  num_applicants  \
# 0  California, United States  3 months ago            45.0
# 1              Palo Alto, CA  2 months ago           187.0
# 2    South San Francisco, CA   1 month ago           153.0
# 3              San Diego, CA    1 week ago            96.0
# 4              San Diego, CA  2 months ago             NaN
#
#                       seniority             employment  \
# 0              Mid-Senior level               Contract
# 1              Mid-Senior level              Full-time
# 2                Not Applicable              Full-time
# 3              Mid-Senior level              Full-time
# 4                Not Applicable              Full-time
#
#                                                       function  \
# 0                                                        Other
# 1                Research, Analyst, and Information Technology
# 2                Research, Analyst, and Information Technology
# 3                                                     Research
# 4                Research, Analyst, and Information Technology
#
#                                                                  industries  \
# 0                                                   Staffing and Recruiting
# 1                                                    Biotechnology Research
# 2                                                    Biotechnology Research
# 3              Non-profit Organizations and Primary and Secondary Education
# 4                       Transportation, Logistics, Supply Chain and Storage
#
#             salary  ...  \
# 0              NaN  ...
# 1   $75,000.00/yr   ...
# 2  $120,000.00/yr   ...
# 3  $100,000.00/yr   ...
# 4              NaN  ...
#
#                                                                                                                        skills_found  \
# 0                                              [Machine Learning, AI, Research, Databases, Bioinformatics, Data Science, Python, R]
# 1                                               [AI, AI, Research, Sequencing, Databases, Bioinformatics, Data Analysis, Python, R]
# 2                                                  [Machine Learning, ML, AI, Sequencing, Bioinformatics, Data Analysis, Python, R]
# 3                                                                      [AI, Research, Sequencing, Bioinformatics, Data Analysis, R]
# 4  [Machine Learning, ML, AI, Deep Learning, AI, Research, Sequencing, Databases, Databases, Bioinformatics, Data Visualization, R]
#
#                                         academic_qualification  \
# 0  [Doctorate, Doctorate, Doctorate, Master's, Post Doctorate]
# 1                                                           []
# 2                                                  [Doctorate]
# 3       [Bachelor's, Doctorate, Doctorate, Master's, Master's]
# 4                                                  [Doctorate]
#
#   Programming Languages Cloud Platforms Data Visualization  \
# 0                     2               0                  0
# 1                     2               0                  0
# 2                     2               0                  0
# 3                     1               0                  0
# 4                     1               0                  0
#
#   Sequencing Technologies Machine Learning & AI Bioinformatics  Databases  \
# 0                       0                     2              0          1
# 1                       0                     1              0          0
# 2                       0                     2              0          0
# 3                       0                     1              0          0
# 4                       0                     3              0          0
#
#    Other Tools
# 0            0
# 1            1
# 2            0
# 3            0
# 4            1
#
# [5 rows x 26 columns]

# %%
# df_final = df.copy()

# %%
df.columns
# Out:
# Index(['Job_title', 'company_name', 'location', 'time_posted',
#        'num_applicants', 'seniority', 'employment', 'function', 'industries',
#        'salary', 'description', 'cleaned_description', 'tokens',
#        'lemmatized_tokens', 'final_cleaned_description', 'tools_found',
#        'skills_found', 'academic_qualification'],
#       dtype='object')

# %%
df_final.columns
# Out:
# Index(['Job_title', 'company_name', 'location', 'time_posted',
#        'num_applicants', 'seniority', 'employment', 'function', 'industries',
#        'salary', 'description', 'cleaned_description', 'tokens',
#        'lemmatized_tokens', 'final_cleaned_description', 'tools_found',
#        'skills_found', 'academic_qualification', 'Programming Languages',
#        'Cloud Platforms', 'Data Visualization', 'Sequencing Technologies',
#        'Machine Learning & AI', 'Bioinformatics', 'Databases', 'Other Tools'],
#       dtype='object')

# %%
df_final.describe()
# Out:
#        num_applicants  Programming Languages  Cloud Platforms  \
# count     1022.000000            3025.000000      3025.000000
# mean        71.214286               1.310413         0.118347
# std         44.090638               0.843886         0.410523
# min         25.000000               0.000000         0.000000
# 25%         36.000000               1.000000         0.000000
# 50%         57.000000               1.000000         0.000000
# 75%         92.000000               1.000000         0.000000
# max        198.000000               8.000000         3.000000
#
#        Data Visualization  Sequencing Technologies  Machine Learning & AI  \
# count         3025.000000              3025.000000            3025.000000
# mean             0.027769                 0.018843               1.038347
# std              0.192164                 0.145394               0.582923
# min              0.000000                 0.000000               0.000000
# 25%              0.000000                 0.000000               1.000000
# 50%              0.000000                 0.000000               1.000000
# 75%              0.000000                 0.000000               1.000000
# max              2.000000                 2.000000               4.000000
#
#        Bioinformatics    Databases  Other Tools
# count      3025.00000  3025.000000  3025.000000
# mean          0.11405     0.074711     0.912727
# std           0.33514     0.301624     0.856225
# min           0.00000     0.000000     0.000000
# 25%           0.00000     0.000000     0.000000
# 50%           0.00000     0.000000     1.000000
# 75%           0.00000     0.000000     1.000000
# max           2.00000     3.000000     8.000000

# %% [markdown]
# ## Visuals

# %% [markdown]
# ### Style guide

# %%
# Set the theme for seaborn
sns.set_theme(
    context='notebook',
    style='whitegrid',
    palette=['#27ae61'],
    font_scale=1.2,
    rc={
        'axes.titlesize': 25,
        'axes.labelsize': 15,
        'xtick.labelsize': 13,
        'ytick.labelsize': 13,
        "axes.spines.right": False,
        "axes.spines.top": False,
        # "axes.spines.left": False,
         "figure.subplot.top": 0.9
    }
)

# %%
# Function to annotate bars
def annotate_bars(ax, orient='v', space=0.5, rotation=0, color='black', fmt='{:.2f}', fontsize=10):
    for p in ax.patches:
        if orient == 'v':  # Vertical bars
            value = p.get_height()
            x = p.get_x() + p.get_width() / 2
            y = value + space
            ha, va = 'center', 'bottom'
        else:  # Horizontal bars
            value = p.get_width()
            x = value + space
            y = p.get_y() + p.get_height() / 2
            ha, va = 'left', 'center'

        # Only annotate if value is finite
        if np.isfinite(value):
            ax.text(x, y, fmt.format(value), ha=ha, va=va, rotation=rotation, color=color, fontsize=fontsize)

# %% [markdown]
# ### Plots

# %%
# Aggregate counts for each technology category
category_counts = df_final.sum(numeric_only=True).drop('num_applicants').sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, color='#27ae61')
plt.xticks(rotation=45, ha='right')
plt.title('Skills Frequency in Job Postings')
plt.xlabel('Technology Category')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=12)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific programming languages to check
specific_languages = ['Python', 'R', 'Java', 'C++', 'Javascript', 'bash', "SQL", "Perl", "HTML",]

# Initialize a dictionary to store the counts
language_counts = {lang: 0 for lang in specific_languages}

# Count the mentions of each specific programming language
for lang in specific_languages:
    # Check if the language is mentioned in each job description
    language_counts[lang] = df_final['tools_found'].apply(lambda tools: lang in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
sorted_language_counts = sorted(language_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted languages and their counts
languages, counts = zip(*sorted_language_counts)

# Create a bar plot for specific programming languages
plt.figure(figsize=(10, 5))
sns.barplot(x=list(languages), y=list(counts), color='#27ae61')
plt.title('Frequency of Progamming Languages in Job Postings')
plt.xlabel('Programming Language')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=12)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific programming languages to check
cloud_platforms = ["AWS", "GCP", "Azure"]


# Initialize a dictionary to store the counts
platform_counts = {platform: 0 for platform in cloud_platforms}

# Count the mentions of each specific programming language
for platform in cloud_platforms:
    # Check if the language is mentioned in each job description
    platform_counts[platform] = df_final['tools_found'].apply(lambda tools: platform in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
sorted_platform_counts = sorted(platform_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted languages and their counts
platforms, counts = zip(*sorted_platform_counts)

# Create a bar plot for specific programming languages
plt.figure(figsize=(10, 5))
sns.barplot(x=list(platforms), y=list(counts), color='#27ae61')
plt.title('Frequency of Cloud Platforms in Job Postings')
plt.xlabel('Cloud Platform')
plt.ylabel('')
plt.yticks([])
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific programming languages to check
other_tools = ["Microsoft Office", "Excel", "SharePoint", "Teams", "Rservers", "Rshiny", "RMarkdown", "VBA",
        "KEGG", "Reactome", "PDB", "Shiny", "Unix", "Hamilton Star", "Beckman Echo", "Scrum", "Kanban", "Docker", "Conda", "Git", "GitHub"]


# Initialize a dictionary to store the counts
other_tools_counts = {_tools: 0 for _tools in other_tools}

# Count the mentions of each specific programming language
for _tools in other_tools:
    # Check if the language is mentioned in each job description
    other_tools_counts[_tools] = df_final['tools_found'].apply(lambda tools: _tools in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
sorted_other_tools_counts = sorted(other_tools_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted languages and their counts
_tools, counts = zip(*sorted_other_tools_counts)

# Create a bar plot for specific programming languages
plt.figure(figsize=(10, 5))
sns.barplot(y=list(_tools), x=list(counts), color='#27ae61')
plt.title('Frequency of Other Tools in Job Postings')
plt.ylabel('Tool')
plt.xlabel('')
plt.xticks([])
plt.yticks(fontsize=12)
plt.tight_layout()
annotate_bars(plt.gca(), orient='h', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific programming languages to check
databases = ["TCGA", "DepMap", "gnomAD", "NCBI SRA", "ENCODE"]

# Initialize a dictionary to store the counts
databases_counts = {database: 0 for database in databases}

# Count the mentions of each specific programming language
for database in databases:
    # Check if the language is mentioned in each job description
    databases_counts[database] = df_final['tools_found'].apply(lambda tools: database in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
databases_counts = sorted(databases_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted languages and their counts
database, counts = zip(*databases_counts)

# Create a bar plot for specific programming languages
plt.figure(figsize=(10, 5))
sns.barplot(x=list(database), y=list(counts), color='#27ae61')
plt.title('Frequency of Databases in Job Postings')
plt.xlabel('Database')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=12)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific data visualization tools to check
data_viz_tools = ["Power BI", "Tableau", "SPSS"]

# Initialize a dictionary to store the counts
data_viz_counts = {tool: 0 for tool in data_viz_tools}

# Count the mentions of each data visualization tool
for tool in data_viz_tools:
    # Check if the tool is mentioned in each job description
    data_viz_counts[tool] = df_final['tools_found'].apply(lambda tools: tool in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
sorted_data_viz_counts = sorted(data_viz_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted tools and their counts
tools, counts = zip(*sorted_data_viz_counts)

# Create a bar plot for data visualization tools
plt.figure(figsize=(10, 5))
sns.barplot(x=list(tools), y=list(counts), color='#27ae61')
plt.title('Frequency of Data Visualization Tools in Job Postings')
plt.xlabel('Data Visualization Tool')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=12)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific sequencing technologies to check
sequencing_tech = ["RNA-seq", "ChIP-seq", "ATAC-seq", "scRNA-seq", "WGS", "Bulk Sequencing", "Single Cell Sequencing"]

# Initialize a dictionary to store the counts
sequencing_counts = {tech: 0 for tech in sequencing_tech}

# Count the mentions of each sequencing technology
for tech in sequencing_tech:
    # Check if the technology is mentioned in each job description
    sequencing_counts[tech] = df_final['tools_found'].apply(lambda tools: tech in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
sorted_sequencing_counts = sorted(sequencing_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted technologies and their counts
technologies, counts = zip(*sorted_sequencing_counts)

# Create a bar plot for sequencing technologies
plt.figure(figsize=(10, 5))
sns.barplot(x=list(technologies), y=list(counts), color='#27ae61')
plt.title('Frequency of Sequencing Technologies in Job Postings')
plt.xlabel('Sequencing Technology')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=10.5)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific machine learning and AI tools to check
ml_ai_tools = ['Machine Learning', 'Deep Learning', 'AI', 'CNN']

# Initialize a dictionary to store the counts
ml_ai_counts = {tool: 0 for tool in ml_ai_tools}

# Count the mentions of each machine learning and AI tool
for tool in ml_ai_tools:
    # Check if the tool is mentioned in each job description
    ml_ai_counts[tool] = df_final['tools_found'].apply(lambda tools: tool in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
sorted_ml_ai_counts = sorted(ml_ai_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted tools and their counts
tools, counts = zip(*sorted_ml_ai_counts)

# Create a bar plot for machine learning and AI tools
plt.figure(figsize=(10, 5))
sns.barplot(x=list(tools), y=list(counts), color='#27ae61')
plt.title('Frequency of Machine Learning & AI Tools in Job Postings')
plt.xlabel('Machine Learning & AI Tool')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=10.5)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# List of specific bioinformatics tools to check
bioinformatics_tools = ['CRISPR', 'Perturb-Seq', 'Imaging', 'REST API']

# Initialize a dictionary to store the counts
bioinformatics_counts = {tool: 0 for tool in bioinformatics_tools}

# Count the mentions of each bioinformatics tool
for tool in bioinformatics_tools:
    # Check if the tool is mentioned in each job description
    bioinformatics_counts[tool] = df_final['tools_found'].apply(lambda tools: tool in tools).sum()

# Convert the counts dictionary to a sorted list of tuples
sorted_bioinformatics_counts = sorted(bioinformatics_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the sorted tools and their counts
tools, counts = zip(*sorted_bioinformatics_counts)

# Create a bar plot for bioinformatics tools
plt.figure(figsize=(10, 5))
sns.barplot(x=list(tools), y=list(counts), color='#27ae61')
plt.title('Frequency of Bioinformatics Tools in Job Postings')
plt.xlabel('Bioinformatics Tool')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=10.5)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# Aggregate the academic qualifications
qualification_counts = df['academic_qualification'].explode().value_counts().sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=qualification_counts.index, y=qualification_counts.values, color='#27ae61')
plt.title('Count of Academic Qualifications Mentioned in Job Descriptions')
plt.xlabel('Academic Qualification')
plt.ylabel('')
plt.yticks([])
plt.xticks(fontsize=12)
plt.tight_layout()
annotate_bars(plt.gca(), orient='v', space=0.5, rotation=0, color='black', fmt='{:.0f}', fontsize=13)
plt.show()

# %%
# Aggregate the academic qualifications
qualification_counts = df['academic_qualification'].explode().value_counts().sort_values(ascending=False)

# Identify the highest category
highest_category = qualification_counts.idxmax()

# Create a list of colors
base_color = '#27ae61'  # Emphasized color for the highest category
other_color = '#a4ddbd'  # Less important color for other categories

# Generate colors based on the category
colors = [base_color if category == highest_category else other_color for category in qualification_counts.index]

# Create a bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=qualification_counts.index, y=qualification_counts.values, palette=colors)

# Setting the titles and labels
plt.title('Count of Academic Qualifications Mentioned in Job Descriptions')
plt.xlabel('Academic Qualification')
plt.ylabel('Count')
plt.xticks(rotation=0)

# Show the plot
plt.show()
